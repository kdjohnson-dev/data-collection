# %%
from openpyxl import load_workbook

# %%
workbook = load_workbook(filename='../data/sample.xlsx')
sheet = workbook.active
sheet.dimensions
# Out:
# 'A1:O100'

# %%
sheet.auto_filter.ref = "A1:O100"
workbook.save(filename='../data/sample_with_filters.xlsx')

# %%
from openpyxl.utils import FORMULAE

# %%
FORMULAE
# Out:
# frozenset({'ABS',
#            'ACCRINT',
#            'ACCRINTM',
#            'ACOS',
#            'ACOSH',
#            'AMORDEGRC',
#            'AMORLINC',
#            'AND',
#            'AREAS',
#            'ASC',
#            'ASIN',
#            'ASINH',
#            'ATAN',
#            'ATAN2',
#            'ATANH',
#            'AVEDEV',
#            'AVERAGE',
#            'AVERAGEA',
#            'AVERAGEIF',
#            'AVERAGEIFS',
#            'BAHTTEXT',
#            'BESSELI',
#            'BESSELJ',
#            'BESSELK',
#            'BESSELY',
#            'BETADIST',
#            'BETAINV',
#            'BIN2DEC',
#            'BIN2HEX',
#            'BIN2OCT',
#            'BINOMDIST',
#            'CEILING',
#            'CELL',
#            'CHAR',
#            'CHIDIST',
#            'CHIINV',
#            'CHITEST',
#            'CHOOSE',
#            'CLEAN',
#            'CODE',
#            'COLUMN',
#            'COLUMNS',
#            'COMBIN',
# ...

# %%
sheet["P2"] = "=AVERAGE(H2:H100)"
sheet["P3"] = '=COUNTIF(I2:I100, ">0")'
workbook.save(filename='../data/sample_formulas.xlsx')
